# %% [markdown]
# # Test Our Approach
#
# Difference between evaluation and testing: for evaluation, we always use the ground truth annotation to extract the contour points. For testing, we can only use the first ground truth annotation to extract the contour points and then need to create the next annotation by using our predicted translations.
#
# Pipeline for testing:
# - Take first ground truth annotation of sequence as input
# - Extract contour_0
# - Create data object
# - Forward pass data through model to get translation_0_1
# - Compute contour_1 = contour_0 + translation_0_1
# - Get OSVOS image
# - Compute combo image

# %% [markdown]
# ## Imports

# %%
import os

import cv2
import matplotlib.pyplot as plt
import numpy as np
import torch 

from pg_networks.gcn import GCN
import src.config as cfg
from src.create_data import create_osvos_model, create_data
from src.metrics import db_eval_iou, db_eval_boundary, db_eval_t_stab
from src.vis_utils import compute_combo_img, extract_longest_contour, load_gray_img

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load OSVOS model to extract feature vectors

# %%
osvos_model = create_osvos_model(cfg.PARENT_MODEL_PATH, cfg.LAYER)
# Out:
# Constructing OSVOS architecture..
# Initializing weights..

# %% [markdown]
# # Load GCN model

# %%
gcn_model_path = 'pg_models/Bear_overfit_model.pth'
gcn_model = GCN(256, 2)
gcn_model.load_state_dict(torch.load(gcn_model_path))
gcn_model.eval()
gcn_model.double()
# Out:
# GCN(
#   (conv1): GCNConv(256, 512)
#   (conv2): GCNConv(512, 512)
#   (conv3): GCNConv(512, 1024)
#   (conv4): GCNConv(1024, 1024)
#   (lin1): Linear(in_features=1024, out_features=512, bias=True)
#   (lin2): Linear(in_features=512, out_features=256, bias=True)
#   (lin3): Linear(in_features=256, out_features=2, bias=True)
# )

# %%
def testing(simple_contour_prediction=True, combo_contour_prediction=False):
    mean_Js_combo = []
    mean_Js_osvos = []

    mean_Fs_combo = []
    mean_Fs_osvos = []

    # Iterate through val sequences
    for i, sequence in enumerate(cfg.VAL_SEQUENCES):

        #if i > 0: break
        print('#{}: {}'.format(i, sequence))

        # Get list of frames
        raw_images_path = os.path.join('pg_datasets/DAVIS_2016/raw/Images', sequence, '0')
        raw_annotations_path = os.path.join('pg_datasets/DAVIS_2016/raw/Annotations', sequence, '0')

        # Get list of frames
        frames = os.listdir(raw_images_path)
        if '.ipynb_checkpoints' in frames:
            frames.remove('.ipynb_checkpoints')
        frames.sort()

        Js_combo = []
        Js_osvos = []

        Fs_combo = []
        Fs_osvos = []    

        # Iterate through frames
        for j, frame in enumerate(frames[:-1]):

            #if j > 5: break
            #print('\t#{}: {}'.format(j, frame))
            
            # If first frame, extract contour from gt annotation
            if j == 0:
                annotation_0_path = os.path.join(raw_annotations_path, frame[:5] + '.png')
                annotation_0_gray = load_gray_img(annotation_0_path)
                
                contour_0 = extract_longest_contour(np.uint8(annotation_0_gray), 
                                                    cfg.CLOSING_KERNEL_SIZE, 
                                                    cv2.CHAIN_APPROX_TC89_KCOS)
                contour_0 = np.squeeze(contour_0)

            # Create data object
            image_path_0 = os.path.join(raw_images_path, frames[j])
            image_path_1 = os.path.join(raw_images_path, frames[j+1])
            print(image_path_0)
            data = create_data(contour_0, None, image_path_0, image_path_1, osvos_model, cfg.K)

            # Forward pass to get outputs
            with torch.no_grad():
                translation_0_1_pred = gcn_model(data)    

            # Compute contour_1
            contour_1_pred = np.add(contour_0, translation_0_1_pred)

            # Load OSVOS result image
            osvos_img_1_path = os.path.join(cfg.OSVOS_RESULTS_FOLDERS_PATH, 
                                            sequence, frames[j+1][:5] + '.png')
            osvos_img_1 = cv2.imread(osvos_img_1_path)
            osvos_img_1_gray = cv2.imread(osvos_img_1_path, cv2.IMREAD_GRAYSCALE)

            # Create combined image
            _, combo_img_1, _, _ = compute_combo_img(contour_1_pred, osvos_img_1)
            combo_img_1_path = os.path.join(cfg.COMBO_RESULTS_FOLDERS_PATH, 
                                            sequence, frames[j+1][:5] + '.png')
            combo_img_1_blended_path = os.path.join(cfg.COMBO_RESULTS_FOLDERS_PATH, 
                                            sequence, frames[j+1][:5] + '_blended.png')            
            if not os.path.exists(os.path.join(cfg.COMBO_RESULTS_FOLDERS_PATH, sequence)):
                os.makedirs(os.path.join(cfg.COMBO_RESULTS_FOLDERS_PATH, sequence))

            cv2.imwrite(combo_img_1_path, combo_img_1*255)
            blended = (0.4 * cv2.imread(image_path_1, cv2.IMREAD_GRAYSCALE) + (0.6 * combo_img_1*255)).astype("uint8")
            cv2.imwrite(combo_img_1_blended_path, blended)
            
            # Load ground truth annotation
            annotation_1_path = os.path.join(raw_annotations_path, frames[j+1][:5] + '.png')
            annotation_1_gray = cv2.imread(annotation_1_path, cv2.IMREAD_GRAYSCALE)

            #Compute J
            J_combo = db_eval_iou(annotation_1_gray, combo_img_1)
            J_osvos = db_eval_iou(annotation_1_gray, osvos_img_1_gray)

            #Compute F
            F_combo = db_eval_boundary(combo_img_1, annotation_1_gray)
            F_osvos = db_eval_boundary(osvos_img_1_gray, annotation_1_gray)

            Js_combo.append(J_combo)
            Js_osvos.append(J_osvos)
            Fs_combo.append(F_combo)
            Fs_osvos.append(F_osvos)
            
            #if combo image completey dark we lost object and cant recover
            if np.sum(combo_img_1) == 0:
                break
            
            if simple_contour_prediction == True:
                contour_0 = contour_1_pred.numpy()
            elif combo_contour_prediction == True:
                contour_0 = extract_longest_contour(np.uint8(combo_img_1*255), 
                                                    cfg.CLOSING_KERNEL_SIZE, 
                                                    cv2.CHAIN_APPROX_TC89_KCOS)
                contour_0 = np.squeeze(contour_0)

        mean_J_combo = np.mean(np.array(Js_combo))
        mean_J_osvos = np.mean(np.array(Js_osvos))
        mean_F_combo = np.mean(np.array(Fs_combo))
        mean_F_osvos = np.mean(np.array(Fs_osvos))

        print('\tmean_J_combo: {}, mean_J_osvos: {}'.format(mean_J_combo, mean_J_osvos))
        print('\tmean_F_combo: {}, mean_F_osvos: {}'.format(mean_F_combo, mean_F_osvos))

        mean_Js_combo.append(mean_J_combo)
        mean_Js_osvos.append(mean_J_osvos)
        mean_Fs_combo.append(mean_F_combo)
        mean_Fs_osvos.append(mean_F_osvos)

    mean_J_combo_overall = np.mean(np.array(mean_Js_combo))
    mean_J_osvos_overall = np.mean(np.array(mean_Js_osvos))
    mean_F_combo_overall = np.mean(np.array(mean_Fs_combo))
    mean_F_osvos_overall = np.mean(np.array(mean_Fs_osvos))

    print('mean_J_combo_overall: {}'.format(mean_J_combo_overall))
    print('mean_J_osvos_overall: {}'.format(mean_J_osvos_overall))
    print('mean_F_combo_overall: {}'.format(mean_F_combo_overall))
    print('mean_F_osvos_overall: {}'.format(mean_F_osvos_overall))

# %%
testing(simple_contour_prediction=False, combo_contour_prediction=True)
# Out:
# #0: blackswan
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00000.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00001.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00002.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00003.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00004.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00005.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00006.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00007.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00008.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00009.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00010.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00011.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00012.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00013.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00014.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00015.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00016.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00017.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00018.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00019.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00020.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00021.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00022.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00023.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00024.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00025.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00026.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00027.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00028.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00029.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00030.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00031.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00032.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00033.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00034.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00035.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00036.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00037.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00038.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00039.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00040.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00041.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00042.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00043.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00044.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00045.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00046.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00047.jpg
# pg_datasets/DAVIS_2016/raw/Images/blackswan/0/00048.jpg
# 	mean_J_combo: 0.9441423916810754, mean_J_osvos: 0.9437691704591111
# 	mean_F_combo: 0.9732060089815633, mean_F_osvos: 0.9702698124832759
# #1: bmx-trees
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00000.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00001.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00002.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00003.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00004.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00005.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00006.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00007.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00008.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00009.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00010.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00011.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00012.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00013.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00014.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00015.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00016.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00017.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00018.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00019.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00020.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00021.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00022.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00023.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00024.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00025.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00026.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00027.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00028.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00029.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00030.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00031.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00032.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00033.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00034.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00035.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00036.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00037.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00038.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00039.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00040.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00041.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00042.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00043.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00044.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00045.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00046.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00047.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00048.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00049.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00050.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00051.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00052.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00053.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00054.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00055.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00056.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00057.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00058.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00059.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00060.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00061.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00062.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00063.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00064.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00065.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00066.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00067.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00068.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00069.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00070.jpg
# pg_datasets/DAVIS_2016/raw/Images/bmx-trees/0/00071.jpg
# 	mean_J_combo: 0.43533968746393253, mean_J_osvos: 0.37834921307894603
# 	mean_F_combo: 0.6011976827166392, mean_F_osvos: 0.4933796213679968
# #2: breakdance
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00000.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00001.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00002.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00003.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00004.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00005.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00006.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00007.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00008.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00009.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00010.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00011.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00012.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00013.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00014.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00015.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00016.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00017.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00018.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00019.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00020.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00021.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00022.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00023.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00024.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00025.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00026.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00027.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00028.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00029.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00030.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00031.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00032.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00033.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00034.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00035.jpg
# pg_datasets/DAVIS_2016/raw/Images/breakdance/0/00036.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-93d5a3600eca> in <module>
# ----> 1 testing(simple_contour_prediction=False, combo_contour_prediction=True)
#
# <ipython-input-28-2bd997ce28c0> in testing(simple_contour_prediction, combo_contour_prediction)
#      85
#      86             #Compute F
# ---> 87             F_combo = db_eval_boundary(combo_img_1, annotation_1_gray)
#      88             F_osvos = db_eval_boundary(osvos_img_1_gray, annotation_1_gray)
#      89
#
# ~/in2364-adl4cv/src/metrics.py in db_eval_boundary(foreground_mask, gt_mask, bound_th)
#      32         from skimage.morphology import binary_dilation,disk
#      33
# ---> 34         fg_dil = binary_dilation(fg_boundary,disk(bound_pix))
#      35         gt_dil = binary_dilation(gt_boundary,disk(bound_pix))
#      36
#
# /opt/anaconda3/lib/python3.7/site-packages/skimage/morphology/misc.py in func_out(image, selem, *args, **kwargs)
#      37         if selem is None:
#      38             selem = _default_selem(image.ndim)
# ---> 39         return func(image, selem=selem, *args, **kwargs)
#      40
#      41     return func_out
#
# /opt/anaconda3/lib/python3.7/site-packages/skimage/morphology/binary.py in binary_dilation(image, selem, out)
#      75     if out is None:
#      76         out = np.empty(image.shape, dtype=np.bool)
# ---> 77     ndi.binary_dilation(image, structure=selem, output=out)
#      78     return out
#      79
#
# /opt/anaconda3/lib/python3.7/site-packages/scipy/ndimage/morphology.py in binary_dilation(input, structure, iterations, mask, output, border_value, origin, brute_force)
#     505
#     506     return _binary_erosion(input, structure, iterations, mask,
# --> 507                            output, border_value, origin, 1, brute_force)
#     508
#     509
#
# /opt/anaconda3/lib/python3.7/site-packages/scipy/ndimage/morphology.py in _binary_erosion(input, structure, iterations, mask, output, border_value, origin, invert, brute_force)
#     243     if iterations == 1:
#     244         _nd_image.binary_erosion(input, structure, mask, output,
# --> 245                                  border_value, origin, invert, cit, 0)
#     246         return output
#     247     elif cit and not brute_force:
#
# KeyboardInterrupt:
