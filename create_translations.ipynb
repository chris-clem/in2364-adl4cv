# %% [markdown]
# # Create Translations for DAVIS 2016 Contours
#
# In this notebook translations between points of two consecutive contours are saved as numpy arrarys.

# %% [markdown]
# ## Example
#
# For two consecutive contours from the annotations of the DAVIS 2016 dataset, the closest points are matched and then the translations are calculated and saved as a numpy array. Initially, there are twice as many contour points on the second contour, so that each point from the first contour finds a close neighbour. After the matching, the points from the second contour that are not matched get discarded and the contour is saved again as a numpy array.
#
# In this picture, the points from the first contour are in red and the one from the second contour in green. The small blue arrows represent the translations of each point.
#
# <img src="Images/bear_annotation_translations.jpeg" alt="bear_annotation_translations" width="512"/>

# %% [markdown]
# ## Imports

# %%
import numpy as np
import os
from scipy import spatial

# %% [markdown]
# ## Paths

# %%
CONTOURS_FOLDERS_PATH = 'DAVIS_2016/DAVIS/Contours/480p'
TRANSLATIONS_FOLDERS_PATH = 'DAVIS_2016/DAVIS/Translations/480p'

# %% [markdown]
# ## Functions

# %%
def get_min_indices(distances):
    '''Returns a (N, 2) array containing the indices of the smallest distances
       sorted in ascending order given a (N, N) distance matrix.'''
    
    # Get indices that sort array by minimal distance
    min_indices = np.argsort(distances, axis=None)

    # Turn array of flat indices into a tuple of coordinate arrays
    min_indices = np.unravel_index(min_indices, distances.shape)

    # Turn tuple of arrays into array of coordinate arrays
    min_indices = np.array([min_indices[0], min_indices[1]])

    # Transpose array
    min_indices = min_indices.T

    return min_indices

# %%
def get_corresponding_points(contour_0, contour_1):
    '''Returns a (N, 2) array containing the matching of the closest contour 
       points given two contours.'''
    
    # Get distance matrix between every point of contour_0 and contour_1
    distances = spatial.distance.cdist(contour_0, contour_1, 'euclidean')
    
    # Get indices of the smallest distances
    min_indices = get_min_indices(distances)
    
    # Compute corresponding points. Each point can only be matched once
    corresponding_points = np.empty([0, 2], int)
    forbidden_points_0 = set()
    forbidden_points_1 = set()
    
    for min_index in min_indices:
        if ((min_index[0] in forbidden_points_0) or 
            (min_index[1] in forbidden_points_1)):
            continue
        else:
            corresponding_points = np.append(corresponding_points, 
                                             min_index.reshape([1,2]),
                                             axis=0)
            forbidden_points_0.add(min_index[0])
            forbidden_points_1.add(min_index[1])
    
    # Sort corresponding points by first column
    corresponding_points = corresponding_points[corresponding_points[:,0].argsort()]
    
    return corresponding_points

# %%
def get_translations(contour_0, contour_1):
    '''Returns the translations for each point in contour_0 to contour_1.'''
    
    # Get corresponding points
    corresponding_points = get_corresponding_points(contour_0, contour_1)
    
    # Compute translations
    translations = np.empty([0, 2], int)
    
    for point in corresponding_points:
        translation = np.subtract(contour_1[point[1]], contour_0[point[0]])
        translations = np.append(translations, translation.reshape([1,2]), axis=0)
    
    return translations, corresponding_points

# %%
def create_translations_for_all_contours(contours_folders_path,
                                         translations_folders_path):
    '''Creates translations for contours and saves them as numpy arrays.'''
    
    # Get list of contours folder (there is one for each sequence)
    contours_folders_list = os.listdir(contours_folders_path)

    # Iterate through folders
    for i, folder in enumerate(contours_folders_list):
        
        # Debug
        #if (i > 1): break

        print('#{}: {}'.format(i, folder))

        # Create folder to save translations
        translations_folder = os.path.join(translations_folders_path, folder)
        if not os.path.exists(translations_folder):
            os.makedirs(translations_folder)

        # Get list of contours (there is one for each frame)
        contours = os.listdir(os.path.join(contours_folders_path, folder))
        if '.ipynb_checkpoints' in contours:
            contours.remove('.ipynb_checkpoints')
        contours.sort()
            
        # Iterate through annotations
        for j, contour in enumerate(contours):

            # Debug
            #if (j > 1): break
                
            # Load contours
            contour_0_path = os.path.join(contours_folders_path, folder, contours[j])
            contour_0 = np.load(contour_0_path)
            
            try:
                contour_1_path = os.path.join(contours_folders_path, folder, contours[j+1])
                contour_1 = np.load(contour_1_path)
            except IndexError as e:
                break

            # Get translations
            translations_0_1, corresponding_points = get_translations(contour_0, contour_1)
            
            # Update contour_1 so that it has same amount of points as contour_0
            corresponding_points = corresponding_points.T 
            contour_1 = contour_1[corresponding_points[1]] 

            # Save contour_1
            np.save(contour_1_path, contour_1)
            
            # Save translations
            np.save(os.path.join(translations_folder, contour[:5]), translations_0_1)

# %% [markdown]
# ## Create Translations

# %%
create_translations_for_all_contours(CONTOURS_FOLDERS_PATH,
                                     TRANSLATIONS_FOLDERS_PATH)
# Out:
# #0: swing
# #1: drift-chicane
# #2: lucia
# #3: soapbox
# #4: breakdance
# #5: drift-turn
# #6: mallard-fly
# #7: motorbike
# #8: scooter-gray
# #9: scooter-black
# #10: breakdance-flare
# #11: bus
# #12: elephant
# #13: bmx-trees
# #14: rollerblade
# #15: dance-twirl
# #16: dance-jump
# #17: horsejump-high
# #18: mallard-water
# #19: car-turn
# #20: kite-walk
# kite-walk 00000.npy 127
# kite-walk 00001.npy 127
# kite-walk 00002.npy 127
# kite-walk 00003.npy 127
# kite-walk 00004.npy 127
# kite-walk 00005.npy 127
# kite-walk 00006.npy 127
# kite-walk 00007.npy 127
# kite-walk 00008.npy 127
# kite-walk 00009.npy 127
# kite-walk 00010.npy 127
# kite-walk 00011.npy 127
# kite-walk 00012.npy 127
# kite-walk 00013.npy 127
# kite-walk 00014.npy 127
# kite-walk 00015.npy 127
# kite-walk 00016.npy 127
# kite-walk 00017.npy 127
# kite-walk 00018.npy 127
# kite-walk 00019.npy 127
# kite-walk 00020.npy 127
# kite-walk 00021.npy 127
# kite-walk 00022.npy 127
# kite-walk 00023.npy 127
# kite-walk 00024.npy 127
# kite-walk 00025.npy 127
# kite-walk 00026.npy 127
# kite-walk 00027.npy 127
# kite-walk 00028.npy 127
# kite-walk 00029.npy 127
# kite-walk 00030.npy 127
# kite-walk 00031.npy 127
# kite-walk 00032.npy 127
# kite-walk 00033.npy 127
# kite-walk 00034.npy 127
# kite-walk 00035.npy 127
# kite-walk 00036.npy 127
# kite-walk 00037.npy 127
# kite-walk 00038.npy 127
# kite-walk 00039.npy 127
# kite-walk 00040.npy 127
# kite-walk 00041.npy 127
# kite-walk 00042.npy 127
# kite-walk 00043.npy 127
# kite-walk 00044.npy 127
# kite-walk 00045.npy 127
# kite-walk 00046.npy 127
# kite-walk 00047.npy 127
# kite-walk 00048.npy 127
# kite-walk 00049.npy 127
# kite-walk 00050.npy 127
# kite-walk 00051.npy 127
# kite-walk 00052.npy 127
# kite-walk 00053.npy 127
# kite-walk 00054.npy 127
# kite-walk 00055.npy 127
# kite-walk 00056.npy 127
# kite-walk 00057.npy 127
# kite-walk 00058.npy 127
# kite-walk 00059.npy 127
# kite-walk 00060.npy 127
# kite-walk 00061.npy 127
# kite-walk 00062.npy 127
# kite-walk 00063.npy 127
# kite-walk 00064.npy 127
# kite-walk 00065.npy 127
# kite-walk 00066.npy 127
# kite-walk 00067.npy 127
# kite-walk 00068.npy 127
# kite-walk 00069.npy 127
# kite-walk 00070.npy 127
# kite-walk 00071.npy 127
# kite-walk 00072.npy 127
# kite-walk 00073.npy 127
# kite-walk 00074.npy 127
# kite-walk 00075.npy 127
# kite-walk 00076.npy 127
# kite-walk 00077.npy 127
# kite-walk 00078.npy 127
# #21: dog-agility
# #22: car-shadow
# #23: paragliding-launch
# #24: stroller
# #25: bear
# #26: hockey
# #27: dog
# #28: boat
# #29: car-roundabout
# #30: soccerball
# #31: train
# train 00000.npy 127
# train 00001.npy 127
# train 00002.npy 127
# train 00003.npy 127
# train 00004.npy 127
# train 00005.npy 127
# train 00006.npy 127
# train 00007.npy 127
# train 00008.npy 127
# train 00009.npy 127
# train 00010.npy 127
# train 00011.npy 127
# train 00012.npy 127
# train 00013.npy 127
# train 00014.npy 127
# train 00015.npy 127
# train 00016.npy 127
# train 00017.npy 127
# train 00018.npy 127
# train 00019.npy 127
# train 00020.npy 127
# train 00021.npy 127
# train 00022.npy 127
# train 00023.npy 127
# train 00024.npy 127
# train 00025.npy 127
# train 00026.npy 127
# train 00027.npy 127
# train 00028.npy 127
# train 00029.npy 127
# train 00030.npy 127
# train 00031.npy 127
# train 00032.npy 127
# train 00033.npy 127
# train 00034.npy 127
# train 00035.npy 127
# train 00036.npy 127
# train 00037.npy 127
# train 00038.npy 127
# train 00039.npy 127
# train 00040.npy 127
# train 00041.npy 127
# train 00042.npy 127
# train 00043.npy 127
# train 00044.npy 127
# train 00045.npy 127
# train 00046.npy 127
# train 00047.npy 127
# train 00048.npy 127
# train 00049.npy 127
# train 00050.npy 127
# train 00051.npy 127
# train 00052.npy 127
# train 00053.npy 127
# train 00054.npy 127
# train 00055.npy 127
# train 00056.npy 127
# train 00057.npy 127
# train 00058.npy 127
# train 00059.npy 127
# train 00060.npy 127
# train 00061.npy 127
# train 00062.npy 127
# train 00063.npy 127
# train 00064.npy 127
# train 00065.npy 127
# train 00066.npy 127
# train 00067.npy 127
# train 00068.npy 127
# train 00069.npy 127
# train 00070.npy 127
# train 00071.npy 127
# train 00072.npy 127
# train 00073.npy 127
# train 00074.npy 127
# train 00075.npy 127
# train 00076.npy 127
# train 00077.npy 127
# train 00078.npy 127
# #32: tennis
# #33: parkour
# #34: surf
# surf 00000.npy 127
# surf 00001.npy 127
# surf 00002.npy 127
# surf 00003.npy 127
# goat 00073.npy 127
# goat 00074.npy 127
# goat 00075.npy 127
# goat 00076.npy 127
# goat 00077.npy 127
# goat 00078.npy 127
# goat 00079.npy 127
# goat 00080.npy 127
# goat 00081.npy 127
# goat 00082.npy 127
# goat 00083.npy 127
# goat 00084.npy 127
# goat 00085.npy 127
# goat 00086.npy 127
# goat 00087.npy 127
# goat 00088.npy 127
# #40: rhino
# #41: hike
# #42: motocross-jump
# #43: horsejump-low
# #44: motocross-bumps
# #45: libby
# libby 00000.npy 127
# libby 00001.npy 127
# libby 00002.npy 127
# libby 00003.npy 127
# libby 00004.npy 127
# libby 00005.npy 127
# libby 00006.npy 127
# libby 00007.npy 127
# libby 00008.npy 127
# libby 00009.npy 127
# libby 00010.npy 127
# libby 00011.npy 127
# libby 00012.npy 127
# libby 00013.npy 127
# libby 00014.npy 127
# libby 00015.npy 127
# libby 00016.npy 127
# libby 00017.npy 127
# libby 00018.npy 127
# libby 00019.npy 127
# libby 00020.npy 127
# libby 00021.npy 127
# libby 00022.npy 127
# libby 00023.npy 127
# libby 00024.npy 127
# libby 00025.npy 127
# libby 00026.npy 127
# libby 00027.npy 127
# libby 00028.npy 127
# libby 00029.npy 127
# libby 00030.npy 127
# libby 00031.npy 127
# libby 00032.npy 127
# libby 00033.npy 127
# libby 00034.npy 127
# libby 00035.npy 127
# libby 00036.npy 127
# libby 00037.npy 127
# libby 00038.npy 127
# libby 00039.npy 127
# libby 00040.npy 127
# libby 00041.npy 127
# libby 00042.npy 127
# libby 00043.npy 127
# libby 00044.npy 127
# libby 00045.npy 127
# libby 00046.npy 127
# libby 00047.npy 127
# #46: paragliding
# #47: camel
# #48: blackswan
# #49: bmx-bumps
# bmx-bumps 00037.npy 102
# bmx-bumps 00038.npy 100
# bmx-bumps 00039.npy 100
# bmx-bumps 00040.npy 100
# bmx-bumps 00041.npy 100
# bmx-bumps 00042.npy 100
# bmx-bumps 00043.npy 100
# bmx-bumps 00044.npy 100
# bmx-bumps 00045.npy 100
# bmx-bumps 00046.npy 100
# bmx-bumps 00047.npy 100
# bmx-bumps 00048.npy 100
# bmx-bumps 00049.npy 100
# bmx-bumps 00050.npy 100
# bmx-bumps 00051.npy 100
# bmx-bumps 00052.npy 100
# bmx-bumps 00053.npy 100
# bmx-bumps 00054.npy 100
# bmx-bumps 00055.npy 100
# bmx-bumps 00056.npy 100
# bmx-bumps 00057.npy 100
# bmx-bumps 00058.npy 100
# bmx-bumps 00059.npy 48
# bmx-bumps 00061.npy 48
# bmx-bumps 00075.npy 48
# bmx-bumps 00076.npy 48
# bmx-bumps 00077.npy 48
# bmx-bumps 00078.npy 48
# bmx-bumps 00079.npy 48
# bmx-bumps 00080.npy 48
# bmx-bumps 00081.npy 48
# bmx-bumps 00082.npy 48
# bmx-bumps 00083.npy 48
# bmx-bumps 00084.npy 48
# bmx-bumps 00085.npy 48
# bmx-bumps 00086.npy 48
# bmx-bumps 00087.npy 48
# bmx-bumps 00088.npy 48
